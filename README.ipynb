# %% [markdown]
# # ProtEx
#
# The ultimate goal of this project is to be able to detect selenoproteins in databases which have been incorrectly truncated at the first instance of a Sec codon, which shares the same code (AUG) as the canonical stop codon. For this task, we are planning to apply the pre-trained ESM transformer.

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Fixing some of the issues I'm having with importing modules. 
import sys
sys.path.append('/home/prichter/Documents/protex/src/')

from src.dataset import *
from src.dataset import SequenceDataset
from src.esm import ESMClassifier, esm_train, esm_test
from src.linear import LinearClassifier, linear_train, linear_test
import scipy.stats as stats
import pandas as pd
import torch
from torch.utils.data import DataLoader
import seaborn as sns
import matplotlib.pyplot as plt
import requests
import transformers
from io import StringIO

from plot import *

# %%
def download_data_from_google_drive(url):
    '''
    Read in CSV data from Google Drive into a pandas DataFrame. 
    '''
    text = requests.get(url).text
    df = pd.read_csv(StringIO(text))

    return df

# %% [markdown]
# ## Data and preprocessing
#
# All amino acid sequences were obtained from the UniProt database. The data is in FASTA format for compatibility with the CD-Hit sequence clustering tool.
# 1. `./data/sec.fasta` All peptide sequences tagged in the UniProt database as containing a selenocysteine residue (there are about 20,000). All sequences have been truncated at the first selenocysteine.
# 2. `./data/short.fasta` This dataset serves as true positive instances of short proteins which are *not* incorrectly truncated. This file was generated by using a Gaussian KDE to approximate a length distribution of truncated selenoproteins (in `sec_trunc.fasta`), sampling from the distribution, and downloading sequences from UniProt which match the length.
# 3. `./data/all.fasta` A combination of `sec_trunc.fasta` and `short.fasta`.

# %% [raw]
# # This function overwrites the original UniProt file with the truncated sequences.
# truncate_selenoproteins('/home/prichter/Documents/protex/data/sec.fasta')
#
# # Read the newly-truncated selenoproteins sequences into a DataFrame.
# sec_data = fasta_to_df('/home/prichter/Documents/protex/data/sec.fasta')
# # Use KDE to generate a distribution based on the lengths of the truncated selenoproteins.
# lengths = sec_data['seq'].apply(len).to_numpy()
# dist = stats.gaussian_kde(lengths)
#
# # When I first attempted this, the dataset was extremely unbalanced... way more selenoproteins.
# download_short_proteins(dist, '/home/prichter/Documents/protex/short.fasta')

# %% [markdown]
# ### Generating train and test data
#
# The The CD-Hit protein clustering tool was used to organize the sequences contained in `all.fasta` into clusters with 80 percent similarity. This was done using the command `cd-hit -i all.fasta -o all -n 5 -c 0.8`. Clustering the sequences, and organizing the training and testing sets such that no cluster spans the two, helps to ensure that the test accuracy captures whether or not the model is generalizing (similar to the approach [here](https://www.biorxiv.org/content/10.1101/626507v4.full)).

# %% [raw]
# # Load in the clustering and sequence information.
# clstr_data = clstr_to_df('/home/prichter/Documents/protex/data/all.clstr')
# fasta_data = fasta_to_df('/home/prichter/Documents/protex/data/all.fasta')
#
# data = clstr_data.merge(fasta_data, how='inner', on='id') # Need to combine the two DataFrames according to the ID column, using intersection of keys from both frames.
# data = data.drop_duplicates(subset=['id']) # Make sure there are no duplicates (I was running into some issues with this)

# %% [markdown]
# Using a greedy partitioning algorithm, the combined dataset was split into a train and test set (with a roughly 75%/25% train/test split). This partitioning approach ensures that no cluster group spans both train and test datasets, for the reasons mentioned above.

# %% [raw]
# train_data, test_data = train_test_split(data, train_size=0.75, test_size=0.25)
#
# # Confirm that the split sizes are correct.
# train_size = int(len(train_data) / len(data) * 100)
# test_size = int(len(test_data) / len(data) * 100)
#
# print(f'The training dataset makes up {train_size} percent of the total data.')
# print(f'The testing dataset makes up {test_size} percent of the total data.')
#
# # Confirm that there is no cluster overlap.
# train_clusters = set(train_data['cluster'])
# test_clusters = set(test_data['cluster'])
# assert len(train_clusters) + len(test_clusters) == len(train_clusters.union(test_clusters))

# %% [markdown]
# After generating the train and test datasets, I saved the data to CSV files to avoid having to re-run cells more than I need to. These files are also stored in the data directory, and contain the amino acid sequences, unique identifiers, and cluster number.

# %% [raw]
# train_data.to_csv('/home/prichter/Documents/protex/data/train.csv', columns=['seq', 'id', 'cluster'])
# test_data.to_csv('/home/prichter/Documents/protex/data/test.csv', columns=['seq', 'id', 'cluster'])

# %% [markdown]
# After Generating the train and test data, it was uploaded to Google Drive, where it can be downloaded and converted to `pd.DataFrame` objects using the code in the cell below. This allows the data to be accessed from any machine.
#
# After it's downloaded, the data is loaded into a `SequenceDataset` object, which is defined in the `dataset.py` module. This class inherits from the `torch.utils.data.Dataset` class, and allows the data to be easily processed into batches and shuffled using the `torch.utils.data.DataLoader` object.

# %%
# TODO: Something weird is happening with the label generation when I read things in from Google Drive, so just doing
# it from local files for now. 

# The data is stored in Google Drive at the following URLs. We can use the file ID to download the data. 
# train_data_url = 'https://drive.google.com/file/d/11vKxUfYyEUBe1UtQoxezwrYdWuqS7Alx/view?usp=sharing'
# test_data_url = 'https://drive.google.com/file/d/1D43lFsvTAy3n3YgyrwSvw9nFfQl3_9F4/view?usp=sharing'


train_data_url = 'https://drive.google.com/uc?export=download&id=11vKxUfYyEUBe1UtQoxezwrYdWuqS7Alx'
test_data_url = 'https://drive.google.com/uc?export=download&id=1D43lFsvTAy3n3YgyrwSvw9nFfQl3_9F4'
sec_fasta_url = 'https://drive.google.com/uc?export=download&id=1m3LBTMxaGZarOKgSHejRCkfc7cM7xAsv'

# Get the selenoprotein data for generating the labels. 
# sec_data = download_data_from_google_drive(sec_fasta_url, format='fasta')
sec_data = fasta_to_df('/home/prichter/Documents/protex/data/sec.fasta') 

# TODO: I should probably just add the labels as a column. 
# train_data = SequenceDataset(download_data_from_google_drive(train_data_url, format='csv'), sec_data=sec_data)
# test_data = SequenceDataset(download_data_from_google_drive(test_data_url, format='csv'), sec_data=sec_data)

train_data = SequenceDataset(pd.read_csv('/home/prichter/Documents/protex/data/train.csv'), sec_data=sec_data)
test_data = SequenceDataset(pd.read_csv('/home/prichter/Documents/protex/data/test.csv'), sec_data=sec_data)

# Load the data into PyTorch DataLoader objects.
train_loader = DataLoader(train_data, shuffle=True, batch_size=32)
test_loader = DataLoader(test_data, shuffle=False, batch_size=32)

# %% [markdown]
# ## Sequence classification
#
# ### Fine-tuning ESM for sequence classification
#
# The following block of code takes a couple of days to run. I executed it as a script in a Google Compute VM, and saved the losses and fine-tuned model. I tried to configure this so that the model weights could be automatically loaded from Google Drive, but it seems as though the model is too large for this ("Google Drive can't scan this file for viruses."). So, I just pushed the entire pickled model to GitHub (not great, I know, but should work for now.)

# %% [raw]
# # Instantiate the classifier.
# model_esm = ESMClassifier()
# losses_esm = esm_train(model_esm, train_loader, test_loader=test_loader, n_epochs=100)

# %%
model_esm = torch.load('model_esm.pickle', map_location=torch.device('cpu'))
losses_esm = pd.read_csv('losses_esm.csv', usecols=['train', 'test'])
# print(losses_esm.head())

fig, ax = plt.subplots(1)
sns.lineplot(data=losses_esm, ax=ax, palette='Paired')
ax.set_title('EsmForSequenceClassification loss during training')
ax.set_ylabel('binary crossentropy loss')
ax.set_xlabel('epoch')
fig.savefig('esm_loss_during_training.png', format='png')
plt.show()

# %% [markdown]
# ### Training the LinearClassifier benchmark

# %%
model_linear = LinearClassifier() # Uses default embedding dim of 64.
losses_linear = linear_train(model_linear, train_loader, test_loader=test_loader, n_epochs=300)
# Out:
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 3175.95it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 3188.40it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1372.83it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1091.97it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1276.45it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1108.32it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1108.30it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1081.06it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1349.38it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1095.40it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1119.29it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1070.22it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1092.19it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1216.97it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1123.40it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1211.95it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1098.73it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1078.67it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1295.81it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1058.51it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1156.17it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1235.06it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1096.11it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1229.40it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1239.71it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1083.23it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1069.54it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 976.86it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1069.50it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1212.84it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1043.18it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1127.37it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1011.14it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1086.70it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1298.80it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1151.54it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1606.05it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1060.89it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1369.63it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1192.76it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1049.91it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1392.78it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1449.39it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1072.09it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1065.56it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1268.54it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1038.06it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 946.22it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 995.63it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1170.91it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1046.80it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1185.60it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1247.43it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 975.10it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1033.37it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1023.55it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1033.22it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 935.25it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1025.69it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 969.66it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 998.04it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1029.86it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 990.08it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 992.77it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 991.23it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 945.11it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1016.38it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1019.67it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 994.80it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1030.64it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1032.20it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 997.77it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1009.29it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 615.37it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 619.03it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 608.85it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 631.15it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1036.45it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1034.30it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1034.46it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 997.48it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1008.61it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1026.15it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 958.40it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1090.20it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1064.10it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 900.67it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1391.97it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1173.74it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1039.02it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 2152.95it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1173.39it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 580.91it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 819.05it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 749.22it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 637.40it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1248.50it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1064.97it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1287.93it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1045.26it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1447.77it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 894.63it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1085.89it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1105.84it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 985.85it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1438.36it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1251.86it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1000.34it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 2208.30it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 2210.12it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1187.71it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1159.77it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1057.05it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1200.97it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1758.06it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1051.08it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1342.32it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1186.97it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1579.86it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1092.67it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 904.73it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 586.49it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 738.60it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 543.04it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 694.91it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 686.93it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1040.74it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1072.88it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1071.23it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1028.98it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1223.81it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1367.33it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 615.60it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1041.91it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1066.54it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1068.48it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1028.67it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1063.89it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1062.37it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1069.08it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1028.92it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1030.56it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 750.99it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1033.85it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1034.05it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1064.79it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 910.65it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1005.70it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 917.07it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1028.58it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1012.57it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1047.52it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1030.91it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1061.95it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1050.27it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1047.45it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1056.66it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1033.74it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1070.30it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 981.63it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 2275.60it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1846.69it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 944.69it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1059.77it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 607.94it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 645.72it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 642.90it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 645.88it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1038.65it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1031.12it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1048.12it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1035.02it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1165.83it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1068.45it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1045.43it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 753.58it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 772.48it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 985.52it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 556.59it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 645.14it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 620.52it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 658.92it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1046.12it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1041.06it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1070.20it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1033.82it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 659.57it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 957.97it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1025.66it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 987.10it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1000.82it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 991.56it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1033.88it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1029.97it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1013.06it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1032.32it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1014.94it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1974.38it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 714.85it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 843.00it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 672.03it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1208.34it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 612.76it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1161.46it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1169.47it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1028.94it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1035.37it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 999.97it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 994.53it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1037.87it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 992.04it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1037.54it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 994.91it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 938.74it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 980.44it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 594.95it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 637.90it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 621.20it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 561.40it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 727.06it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1065.46it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1104.13it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1032.82it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1321.83it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1127.50it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1020.75it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 2535.35it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1098.68it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1100.76it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1046.76it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 2447.30it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 2260.14it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 2261.49it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1132.34it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1019.47it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1037.96it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1002.48it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 678.15it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 858.08it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 686.48it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 629.52it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1098.43it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1230.25it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1779.26it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1083.97it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1116.30it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1058.07it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1025.85it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1021.89it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1498.76it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1037.08it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1158.60it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1028.05it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 781.24it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 557.36it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 607.63it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 573.93it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 553.85it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 697.29it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1028.95it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1078.03it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1004.73it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1015.20it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1035.77it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 951.39it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1163.28it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1048.56it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1025.70it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1904.20it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 2140.49it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1041.27it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 918.78it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 740.97it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 751.55it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 658.25it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1507.43it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 681.55it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 597.69it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 635.99it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1045.18it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1025.89it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1034.17it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1015.02it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1033.53it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 975.80it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 956.59it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 2270.67it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1279.61it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1044.46it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1003.76it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 991.18it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 986.26it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 992.53it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 837.70it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 614.67it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 656.66it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 748.11it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 720.44it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 917.46it/s]
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 774.31it/s]
# Training classifier...: 100%|██████████| 300/300 [20:43<00:00,  4.15s/it]

# %%
# Save the model weights. 
# torch.save(model_linear, 'model_linear.pickle')

# %%
fig, ax = plt.subplots(1)
sns.lineplot(data=pd.DataFrame(losses_linear), ax=ax, palette='Paired')
ax.set_title('LinearClassifier loss during training')
ax.set_ylabel('binary crossentropy loss')
ax.set_xlabel('epoch')
fig.savefig('linear_loss_during_training_random_init.png', format='png')
plt.show()

# %% [markdown]
# ### Evaluation
#
# To evaluate the models, prediction accuracy was computed for each, as well as the test loss.

# %%
# First, load each trained model from their pickle files. 
model_esm = torch.load('model_esm.pickle', map_location=torch.device('cpu'))
model_linear = torch.load('model_linear.pickle') # This is the model with Xavier initialization.

# %%
# esm_test_loss, esm_accuracy = esm_test(model_esm, test_loader)
print('EsmForSequenceClassification test loss:', esm_test_loss.item())
print('EsmForSequenceClassification classification accuracy:', esm_accuracy)
# Out:
# EsmForSequenceClassification test loss: 0.1365031749010086
# EsmForSequenceClassification classification accuracy: 0.95412457

# %%
linear_test_loss, linear_accuracy = linear_test(model_linear, test_loader)
print('LinearClassifier test loss:', linear_test_loss.item())
print('LinearClassifier classification accuracy:', linear_accuracy)
# Out:
# Calculating batch loss...: 100%|██████████| 297/297 [00:00<00:00, 1369.29it/s]
# LinearClassifier test loss: 0.3180880546569824
# LinearClassifier classification accuracy: 0.8717382

# %% [markdown]
# Just to confirm that fine-tuning the ESM model on the training data improved performance, I also want to check the classification loss. I should note that I am not sure how the weights of the ESM classification head are initialized (i.e. whether they are random, Xavier, pre-trained, etc.).

# %%
# model_esm_original = ESMClassifier() # Don't train this one!

# esm_original_test_loss, esm_original_accuracy = esm_test(model_esm_original, test_loader)
print('EsmForSequenceClassification test loss:', esm_original_test_loss.item())
print('EsmForSequenceClassification classification accuracy:', esm_original_accuracy)
# Out:
# EsmForSequenceClassification test loss: 0.685573160648346
# EsmForSequenceClassification classification accuracy: 0.61858165
